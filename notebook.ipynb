# %%
import pandas as pd
import duckdb
from sqlalchemy import create_engine
from tqdm.auto import tqdm
import click
from pathlib import Path
import argparse
import os

# %%
Path.cwd()
Path(Path.cwd(),"query.sql")
# Out:
# PosixPath('/home/lu-landru/zoocamp/module1/DE-ZoomCamp-Module1-Docker-SQL/query.sql')

# %%
zones = pd.read_csv("https://github.com/DataTalksClub/nyc-tlc-data/releases/download/misc/taxi_zone_lookup.csv")

# %%
tt=  {"a":1,"b":2,"c":3}
#vv= :v for k,v in tt.items() if k!= "a"]
tt.pop("a")
tt
# Out:
# {'b': 2, 'c': 3}

# %%
# Out:
# {'b': 2, 'c': 3}

# %%
zones.dtypes.to_dict()
# Out:
# {'LocationID': dtype('int64'),
#  'Borough': <StringDtype(na_value=nan)>,
#  'Zone': <StringDtype(na_value=nan)>,
#  'service_zone': <StringDtype(na_value=nan)>}

# %%
zones.isnull().sum().to_dict()
# Out:
# {'LocationID': 0, 'Borough': 0, 'Zone': 1, 'service_zone': 2}

# %%
df.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2025-11-01 00:34:48   2025-11-01 00:41:39                  N
# 1         2  2025-11-01 00:18:52   2025-11-01 00:24:27                  N
# 2         2  2025-11-01 01:03:14   2025-11-01 01:15:24                  N
# 3         2  2025-11-01 00:10:57   2025-11-01 00:24:53                  N
# 4         1  2025-11-01 00:03:48   2025-11-01 00:19:38                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0           1            74            42                1           0.74
# 1           1            74            42                2           0.95
# 2           1            83           160                1           2.19
# 3           1           166           127                1           5.44
# 4           1           166           262                1           3.20
#
#    fare_amount  ...  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 0          7.2  ...      0.5        1.94           0.0        NaN
# 1          7.2  ...      0.5        0.00           0.0        NaN
# 2         13.5  ...      0.5        5.00           0.0        NaN
# 3         24.7  ...      0.5        0.50           0.0        NaN
# 4         18.4  ...      1.5        1.00           0.0        NaN
#
#    improvement_surcharge  total_amount  payment_type  trip_type  \
# 0                    1.0         11.64           1.0          1
# 1                    1.0          9.70           2.0          1
# 2                    1.0         21.00           1.0          1
# 3                    1.0         27.70           1.0          1
# 4                    1.0         24.65           1.0          1
#
#    congestion_surcharge  cbd_congestion_fee
# 0                  0.00                 0.0
# 1                  0.00                 0.0
# 2                  0.00                 0.0
# 3                  0.00                 0.0
# 4                  2.75                 0.0
#
# [5 rows x 21 columns]

# %%
### SCHEMA #########

dtype={

 'VendorID': 'Int64',
 'store_and_fwd_flag': 'object',
 'RatecodeID': 'Int64',
 'PULocationID': 'Int64',
 'DOLocationID': 'Int64',
 'passenger_count': 'Int64',
 'trip_distance': 'float64',
 'fare_amount': 'float64',
 'extra': 'float64',
 'mta_tax': 'float64',
 'tip_amount': 'float64',
 'tolls_amount': 'float64',
 'ehail_fee': 'float64',
 'improvement_surcharge': 'float64',
 'total_amount': 'float64',
 'payment_type': 'float64',
 'trip_type': 'Int64',
 'congestion_surcharge': 'float64',
 'cbd_congestion_fee': 'float64'  
}

parse_dates = [
    "lpep_pickup_datetime",
    "lpep_dropoff_datetime"
]
tt = "https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2025-11.parquet"
df = pd.read_parquet(tt).astype(dtype)

# %%
# create a function that:
#1. read csv file 
#2. breks the data into chuncks  of 1000 rowws
#3. the function takes as parameters prefix

dtype = {
  'LocationID': 'int64',
 'Borough':"string" ,
 'Zone': "string",
 'service_zone':"string" }

prefix = "https://github.com/DataTalksClub/nyc-tlc-data/releases/download/misc/" 
file_name = "taxi_zone_lookup"

def read_csv_file(prefix: str, file_name: str, chunksize:int):

  try:
      url = prefix + file_name + ".csv"
      iter_data = pd.read_csv(url,dtype=dtype,chunksize=chunksize,iterator=True)
      return iter_data
  except Exception as e:
     print(f"Unbale to read csv file {e}")  

test = read_csv_file(prefix=prefix,file_name=file_name, chunksize=1000)


for i,t in enumerate(test):
  pd.DataFrame(t)
  print(t)
# Out:
#      LocationID        Borough                     Zone service_zone
# 0             1            EWR           Newark Airport          EWR
# 1             2         Queens              Jamaica Bay    Boro Zone
# 2             3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3             4      Manhattan            Alphabet City  Yellow Zone
# 4             5  Staten Island            Arden Heights    Boro Zone
# ..          ...            ...                      ...          ...
# 260         261      Manhattan       World Trade Center  Yellow Zone
# 261         262      Manhattan           Yorkville East  Yellow Zone
# 262         263      Manhattan           Yorkville West  Yellow Zone
# 263         264        Unknown                       NV         <NA>
# 264         265        Unknown                     <NA>         <NA>
#
# [265 rows x 4 columns]

# %%
################
## VARIABLES###
##############


year = 2025
month = 11
port = 5432
user = "root"
database = "ny_taxi"
host = "localhost"
password = "root"
batch_size = 10000
prefix = "https://d37ci6vzurychx.cloudfront.net/trip-data/"
file_name = "green_tripdata"
target_table = "yellow_taxi_data"



###############################################
## initialize batches to be ingested into db
###############################################


def init_batch(prefix,file_name,batch_size,year,month):

    url =f"{prefix}{file_name}_{year}-{month:02d}.parquet"
    open("query.sql","r").read().format(url)

    con = duckdb.connect()
    con.execute("INSTALL httpfs; LOAD httpfs;")
    record_batch_reader = con.execute(
        f"""
        SELECT VendorID::BIGINT as VendorID ,
               lpep_pickup_datetime::TIMESTAMP as lpep_pickup_datetime ,
               lpep_dropoff_datetime::TIMESTAMP as lpep_dropoff_datetime ,
               store_and_fwd_flag::VARCHAR as store_and_fwd_flag ,
               RatecodeID::BIGINT as RatecodeID ,
               PULocationID::BIGINT as PULocationID ,
               DOLocationID::BIGINT as DOLocationID ,
               passenger_count::BIGINT as passenger_count ,
               trip_distance::DOUBLE as trip_distance ,
               fare_amount::DOUBLE as fare_amount ,
               extra::DOUBLE as extra ,
               mta_tax::DOUBLE as mta_tax ,
               tip_amount::DOUBLE as tip_amount ,
               tolls_amount::DOUBLE as tolls_amount ,
               ehail_fee::DOUBLE as ehail_fee ,
               improvement_surcharge::DOUBLE as improvement_surcharge ,
               total_amount::DOUBLE as total_amount ,
               payment_type::DOUBLE as payment_type ,
               trip_type::BIGINT as trip_type ,
               congestion_surcharge::DOUBLE as congestion_surcharge ,
               cbd_congestion_fee::DOUBLE as cbd_congestion_fee 
        FROM '{url}'
    """).fetch_record_batch(rows_per_batch=batch_size)

    return record_batch_reader



###############################
## ingest batches into database
###############################


def ingest_data(batch_reader,user,password,host,port,database,target_table):

    engine = create_engine(f'postgresql://{user}:{password}@{host}:{port}/{database}')
    first = True

    for batch in tqdm(batch_reader):
        chunk_df = batch
        # try:
        #     chunk_df = batch.to_pandas()
        # except:
        #     chunk_df = pd.DataFrame(batch)

        if first:
            chunk_df.head(n=0).to_sql(name = target_table, con = engine, if_exists = "replace")
            print(pd.io.sql.get_schema(chunk_df, name = target_table,con=engine))
            first = False
        chunk_df.to_sql(name = target_table, con =engine, if_exists = 'append')
        print(f"Processing batch of {len(chunk_df)} rows")



batch_reader = init_batch(prefix=prefix,file_name=file_name,batch_size=batch_size,year=year,month=month)

ingest_data(batch_reader=batch_reader,
            user=user,
            password=password,
            host=host,
            port=port,
            database=database,
            target_table=target_table)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 88
#      83         chunk_df.to_sql(name = target_table, con =engine, if_exists = 'append')
#      84         print(f"Processing batch of {len(chunk_df)} rows")
# ---> 88 batch_reader = init_batch(prefix=prefix,file_name=file_name,batch_size=batch_size,year=year,month=month)
#      90 ingest_data(batch_reader=batch_reader,
#      91             user=user,
#      92             password=password,
#    (...)     95             database=database,
#      96             target_table=target_table)
#
# Cell In[9], line 56, in init_batch(prefix, file_name, batch_size, year, month)
#      30 con = duckdb.connect()
#      31 con.execute("INSTALL httpfs; LOAD httpfs;")
#      32 record_batch_reader = con.execute(
#      33     f"""
#      34     SELECT VendorID::BIGINT as VendorID ,
#      35            lpep_pickup_datetime::TIMESTAMP as lpep_pickup_datetime ,
#      36            lpep_dropoff_datetime::TIMESTAMP as lpep_dropoff_datetime ,
#      37            store_and_fwd_flag::VARCHAR as store_and_fwd_flag ,
#      38            RatecodeID::BIGINT as RatecodeID ,
#      39            PULocationID::BIGINT as PULocationID ,
#      40            DOLocationID::BIGINT as DOLocationID ,
#      41            passenger_count::BIGINT as passenger_count ,
#      42            trip_distance::DOUBLE as trip_distance ,
#      43            fare_amount::DOUBLE as fare_amount ,
#      44            extra::DOUBLE as extra ,
#      45            mta_tax::DOUBLE as mta_tax ,
#      46            tip_amount::DOUBLE as tip_amount ,
#      47            tolls_amount::DOUBLE as tolls_amount ,
#      48            ehail_fee::DOUBLE as ehail_fee ,
#      49            improvement_surcharge::DOUBLE as improvement_surcharge ,
#      50            total_amount::DOUBLE as total_amount ,
#      51            payment_type::DOUBLE as payment_type ,
#      52            trip_type::BIGINT as trip_type ,
#      53            congestion_surcharge::DOUBLE as congestion_surcharge ,
#      54            cbd_congestion_fee::DOUBLE as cbd_congestion_fee
#      55     FROM '{url}'
# ---> 56 """).fetch_record_batch(rows_per_batch=batch_size).to_pandas()
#      58 return record_batch_reader
#
# AttributeError: 'pyarrow.lib.RecordBatchReader' object has no attribute 'to_pandas'

# %%
df.dtypes
# Out:
# VendorID                          Int64
# lpep_pickup_datetime     datetime64[us]
# lpep_dropoff_datetime    datetime64[us]
# store_and_fwd_flag               object
# RatecodeID                        Int64
# PULocationID                      Int64
# DOLocationID                      Int64
# passenger_count                   Int64
# trip_distance                   float64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# ehail_fee                       float64
# improvement_surcharge           float64
# total_amount                    float64
# payment_type                    float64
# trip_type                         Int64
# congestion_surcharge            float64
# cbd_congestion_fee              float64
# dtype: object

# %%
print(open("query.sql","r").read().format('tt'))
# Out:
# SELECT VendorID::BIGINT,
#                lpep_pickup_datetime::TIMESTAMP,
#                lpep_dropoff_datetime::TIMESTAMP,
#                store_and_fwd_flag::VARCHAR,
#                RatecodeID::BIGINT,
#                PULocationID::BIGINT,
#                DOLocationID::BIGINT,
#                passenger_count::BIGINT,
#                trip_distance::DOUBLE,
#                fare_amount::DOUBLE,
#                extra::DOUBLE,
#                mta_tax::DOUBLE,
#                tip_amount::DOUBLE,
#                tolls_amount::DOUBLE,
#                ehail_fee::DOUBLE,
#                improvement_surcharge::DOUBLE,
#                total_amount::DOUBLE,
#                payment_type::DOUBLE,
#                trip_type::BIGINT,
#                congestion_surcharge::DOUBLE,
#                cbd_congestion_fee::DOUBLE
#         FROM 'tt'

# %%
with open('query.sql','r') as q:
  q.read().format('table')
